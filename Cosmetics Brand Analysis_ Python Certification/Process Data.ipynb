# %%
# Import pandas and read in raw data
import pandas as pd
cosmetics = pd.read_csv('cosmetics_old.csv')
cosmetics['brand'].value_counts()
# Out:
# SEPHORA COLLECTION    285
# CLINIQUE              134
# tarte                 100
# Dior                   93
# TOM FORD               93
#                      ...
# OVEROSE                 1
# overose                 1
# glow recipe             1
# Ouai                    1
# THE 7 VIRTUES           1
# Name: brand, Length: 1437, dtype: int64

# %%
## Remove leading and trailing white space in brand column
cosmetics['brand'] = cosmetics['brand'].str.strip()
cosmetics['brand'].value_counts()
# Out:
# SEPHORA COLLECTION     355
# CLINIQUE               166
# tarte                  116
# TOM FORD               116
# Dior                   116
#                       ...
# OVEROSE                  1
# overose                  1
# DR. BRANDT SKINCARE      1
# edible beauty            1
# THE 7 VIRTUES            1
# Name: brand, Length: 738, dtype: int64

# %%
# Write two new processed files to csv
cosmetics.to_csv('cosmetics.csv', index=False)

# %%
cosmetics
# Out:
#            id               brand            category  \
# 0     2218774      Acqua Di Parma             Perfume
# 1     2044816      Acqua Di Parma             Cologne
# 2     1417567      Acqua Di Parma             Perfume
# 3     1417617      Acqua Di Parma             Perfume
# 4     2218766      Acqua Di Parma             Perfume
# ...       ...                 ...                 ...
# 8627  2208502  SEPHORA COLLECTION          Face Masks
# 8628  2298909  SEPHORA COLLECTION            Lip Sets
# 8629  2236750  SEPHORA COLLECTION  Tinted Moisturizer
# 8630       50  sephora collection         no category
# 8631      304  SEPHORA COLLECTION         no category
#
#                                             name              size    price  \
# 0                 Blu Mediterraneo MINIATURE Set    5 x 0.16oz/5mL   USD 66
# 1                                        Colonia     0.7 oz/ 20 mL   USD 66
# 2                               Arancia di Capri      5 oz/ 148 mL  USD 180
# ...
